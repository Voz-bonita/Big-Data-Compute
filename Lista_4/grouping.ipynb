# %%
import requests

# %%
headers = requests.utils.default_headers()
headers.update({"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36"})

# %%
url = "https://cxm-api.fifa.com/fifaplusweb/api/sections/tournamentGroupOverview/15xDmWzQAu51lEIjP4fVfz?locale=en"
response = requests.get(url, headers=headers)

# %%
info = response.json()
info
# Out:
# {'entryType': 'tournamentGroupOverview',
#  'entryId': '15xDmWzQAu51lEIjP4fVfz',
#  'title': 'Groups',
#  'theme': 'Dark',
#  'live': True,
#  'groups': [{'groupTitle': 'Group A',
#    'teams': [{'groupPlacement': 'A1',
#      'name': 'Qatar',
#      'flag': {'title': 'Qatar',
#       'src': 'https://api.fifa.com/api/v3/picture/flags-sq-2/QAT',
#       'alt': 'Qatar'}},
#     {'groupPlacement': 'A2',
#      'name': 'Ecuador',
#      'flag': {'title': 'Ecuador',
#       'src': 'https://api.fifa.com/api/v3/picture/flags-sq-2/ECU',
#       'alt': 'Ecuador'}},
#     {'groupPlacement': 'A3',
#      'name': 'Senegal',
#      'flag': {'title': 'Senegal',
#       'src': 'https://api.fifa.com/api/v3/picture/flags-sq-2/SEN',
#       'alt': 'Senegal'}},
#     {'groupPlacement': 'A4',
#      'name': 'Netherlands',
#      'flag': {'title': 'Netherlands',
#       'src': 'https://api.fifa.com/api/v3/picture/flags-sq-2/NED',
#       'alt': 'Netherlands'}}]},
#   {'groupTitle': 'Group B',
# ...

# %%
grouping = {group["groupTitle"]: [teams["name"] for teams in group["teams"]] for group in info["groups"]}
grouping
# Out:
# {'Group A': ['Qatar', 'Ecuador', 'Senegal', 'Netherlands'],
#  'Group B': ['England', 'IR Iran', 'USA', 'Wales'],
#  'Group C': ['Argentina', 'Saudi Arabia', 'Mexico', 'Poland'],
#  'Group D': ['France', 'Denmark', 'Tunisia', 'Australia'],
#  'Group E': ['Spain', 'Germany', 'Japan', 'Costa Rica'],
#  'Group F': ['Belgium', 'Canada', 'Morocco', 'Croatia'],
#  'Group G': ['Brazil', 'Serbia', 'Switzerland', 'Cameroon'],
#  'Group H': ['Portugal', 'Ghana', 'Uruguay', 'Korea Republic']}

# %%
import json

grp_json = json.dumps(grouping)
with open("grouping.json", "w+") as output:
    output.write(grp_json)
